# %%
import pandas as pd
from pathlib import Path

# %%
june_23_path=Path("../CITYBIKE_CSV/JC-202306-citibike-tripdata.csv")
june_23_data=pd.read_csv(june_23_path)
june_23_df=pd.DataFrame(june_23_data)
june_23_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      37BE5FCB1A385CDA   classic_bike  2023-06-27 16:06:27
# 1      9C96B4C6CBBB31AD   classic_bike  2023-06-24 10:46:58
# 2      C91293605D4BEC07  electric_bike  2023-06-04 20:30:13
# 3      2920063442116A46   classic_bike  2023-06-08 19:10:06
# 4      E205FD8C18BA263A   classic_bike  2023-06-23 18:53:51
# ...                 ...            ...                  ...
# 97018  2C69F8EF2A1BDD90   classic_bike  2023-06-30 19:41:00
# 97019  43E592256BC287BB   classic_bike  2023-06-20 18:55:02
# 97020  4C3A7521689C560C  electric_bike  2023-06-22 19:24:22
# 97021  9AAA8F2E630456E7   classic_bike  2023-06-30 13:34:09
# 97022  064CE90800E9C21F   classic_bike  2023-06-13 17:23:31
#
#                   ended_at             start_station_name start_station_id  \
# 0      2023-06-27 16:10:27                        Hilltop            JC019
# 1      2023-06-24 10:55:27          Baldwin at Montgomery            JC020
# ...

# %%
july_23_path=Path("../CITYBIKE_CSV/JC-202307-citibike-tripdata.csv")
july_23_data=pd.read_csv(july_23_path)
july_23_df=pd.DataFrame(july_23_data)
july_23_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       7A68381621C25F78   classic_bike  2023-07-17 17:16:34
# 1       0F814CA67B2FA120   classic_bike  2023-07-26 19:40:15
# 2       775A38967EBF5FB4  electric_bike  2023-07-01 12:12:22
# 3       D93B742DCE1C1447   classic_bike  2023-07-20 19:10:18
# 4       AA7A6863B4B92169  electric_bike  2023-07-07 19:33:59
# ...                  ...            ...                  ...
# 106603  944F5CD711E7688E   classic_bike  2023-07-25 18:21:52
# 106604  4665B542F79F8C43  electric_bike  2023-07-26 22:22:20
# 106605  789D45FDEBC19E83   classic_bike  2023-07-31 07:57:29
# 106606  FFBE463288D36C2A   classic_bike  2023-07-07 17:52:09
# 106607  4DACECF4EBBEB60C   classic_bike  2023-07-26 20:54:16
#
#                    ended_at     start_station_name start_station_id  \
# 0       2023-07-17 17:20:52            Astor Place            JC077
# 1       2023-07-26 19:44:37        Adams St & 2 St            HB407
# ...

# %%
august_23_path=Path("../CITYBIKE_CSV/JC-202308-citibike-tripdata.csv")
august_23_data=pd.read_csv(august_23_path)
august_23_df=pd.DataFrame(august_23_data)
august_23_df
# Out:
#                  ride_id rideable_type           started_at  \
# 0       E2E964A161F786AB  classic_bike  2023-08-07 19:37:47
# 1       0660F2E48E3BB87F  classic_bike  2023-08-01 13:16:22
# 2       940FC7C675232897  classic_bike  2023-08-15 17:28:23
# 3       E967660CC5CD585B  classic_bike  2023-08-01 12:44:24
# 4       D997CB0B855FE2D6  classic_bike  2023-08-08 12:31:16
# ...                  ...           ...                  ...
# 112022  A579E97D03366092  classic_bike  2023-08-27 18:49:28
# 112023  5A86269B2A06457D  classic_bike  2023-08-12 11:49:02
# 112024  B2BF13B8AC5129AB  classic_bike  2023-08-01 18:53:29
# 112025  3E126EFFE4F64E4D  classic_bike  2023-08-14 11:36:10
# 112026  3D4074EAA1A43EC8  classic_bike  2023-08-17 13:30:35
#
#                    ended_at          start_station_name start_station_id  \
# 0       2023-08-07 19:41:14             6 St & Grand St            HB302
# 1       2023-08-01 13:26:02             6 St & Grand St            HB302
# ...

# %%
print(len(june_23_df["ride_id"].unique()))
print(len(july_23_df["ride_id"].unique()))
print(len(august_23_df["ride_id"].unique()))
# Out:
# 97023
# 106608
# 112027

# %%
print(june_23_df.dtypes)
print(july_23_df.dtypes)
print(august_23_df.dtypes)
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# ...

# %%
print(june_23_df.columns)
print(july_23_data.columns)
print(august_23_df.columns)
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
june23_to_august23_df=pd.concat([june_23_df,july_23_df,august_23_df])
june23_to_august23_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       37BE5FCB1A385CDA   classic_bike  2023-06-27 16:06:27
# 1       9C96B4C6CBBB31AD   classic_bike  2023-06-24 10:46:58
# 2       C91293605D4BEC07  electric_bike  2023-06-04 20:30:13
# 3       2920063442116A46   classic_bike  2023-06-08 19:10:06
# 4       E205FD8C18BA263A   classic_bike  2023-06-23 18:53:51
# ...                  ...            ...                  ...
# 112022  A579E97D03366092   classic_bike  2023-08-27 18:49:28
# 112023  5A86269B2A06457D   classic_bike  2023-08-12 11:49:02
# 112024  B2BF13B8AC5129AB   classic_bike  2023-08-01 18:53:29
# 112025  3E126EFFE4F64E4D   classic_bike  2023-08-14 11:36:10
# 112026  3D4074EAA1A43EC8   classic_bike  2023-08-17 13:30:35
#
#                    ended_at     start_station_name start_station_id  \
# 0       2023-06-27 16:10:27                Hilltop            JC019
# 1       2023-06-24 10:55:27  Baldwin at Montgomery            JC020
# ...

# %%
june23_to_august23_df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
june23_to_august23_df_clean= june23_to_august23_df.dropna(subset=['start_station_id', 'end_station_id'])
june23_to_august23_df_clean
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       37BE5FCB1A385CDA   classic_bike  2023-06-27 16:06:27
# 1       9C96B4C6CBBB31AD   classic_bike  2023-06-24 10:46:58
# 2       C91293605D4BEC07  electric_bike  2023-06-04 20:30:13
# 3       2920063442116A46   classic_bike  2023-06-08 19:10:06
# 4       E205FD8C18BA263A   classic_bike  2023-06-23 18:53:51
# ...                  ...            ...                  ...
# 112022  A579E97D03366092   classic_bike  2023-08-27 18:49:28
# 112023  5A86269B2A06457D   classic_bike  2023-08-12 11:49:02
# 112024  B2BF13B8AC5129AB   classic_bike  2023-08-01 18:53:29
# 112025  3E126EFFE4F64E4D   classic_bike  2023-08-14 11:36:10
# 112026  3D4074EAA1A43EC8   classic_bike  2023-08-17 13:30:35
#
#                    ended_at     start_station_name start_station_id  \
# 0       2023-06-27 16:10:27                Hilltop            JC019
# 1       2023-06-24 10:55:27  Baldwin at Montgomery            JC020
# ...

# %%
null_counts = june23_to_august23_df_clean.isnull().sum()
print(null_counts)
# Out:
# ride_id               0
# rideable_type         0
# started_at            0
# ended_at              0
# start_station_name    0
# start_station_id      0
# end_station_name      0
# end_station_id        0
# start_lat             0
# start_lng             0
# end_lat               0
# end_lng               0
# member_casual         0
# dtype: int64

# %%
june23_to_august23_df_clean.to_csv('../CITYBIKE_CSV/cleaned_citibike_data.csv', index=False)
print(june23_to_august23_df_clean)
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       37BE5FCB1A385CDA   classic_bike  2023-06-27 16:06:27
# 1       9C96B4C6CBBB31AD   classic_bike  2023-06-24 10:46:58
# 2       C91293605D4BEC07  electric_bike  2023-06-04 20:30:13
# 3       2920063442116A46   classic_bike  2023-06-08 19:10:06
# 4       E205FD8C18BA263A   classic_bike  2023-06-23 18:53:51
# ...                  ...            ...                  ...
# 112022  A579E97D03366092   classic_bike  2023-08-27 18:49:28
# 112023  5A86269B2A06457D   classic_bike  2023-08-12 11:49:02
# 112024  B2BF13B8AC5129AB   classic_bike  2023-08-01 18:53:29
# 112025  3E126EFFE4F64E4D   classic_bike  2023-08-14 11:36:10
# 112026  3D4074EAA1A43EC8   classic_bike  2023-08-17 13:30:35
#
#                    ended_at     start_station_name start_station_id  \
# 0       2023-06-27 16:10:27                Hilltop            JC019
# 1       2023-06-24 10:55:27  Baldwin at Montgomery            JC020
# ...
